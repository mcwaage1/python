# 15  2020-01-01 10:04:12      NaN        NaN             NaN        NaN    NaN
# 16   2020-01-01 8:50:50      NaN        NaN             NaN        NaN    NaN
# 17   2020-01-01 8:48:33      NaN        NaN             NaN        NaN    NaN
# 18   2020-01-01 7:21:20      NaN        NaN             NaN        NaN    NaN
# 19   2020-01-01 6:56:52      NaN        NaN             NaN        NaN    NaN
# 20   2020-01-01 6:53:21      NaN        NaN             NaN        NaN    NaN
# 21   2020-01-01 6:45:39      NaN        NaN             NaN        NaN    NaN
# 22   2020-01-01 4:02:15      NaN        NaN             NaN        NaN    NaN
# 23   2020-01-01 3:56:37      NaN        NaN             NaN        NaN    NaN

# %%
dictionary = csv.DictReader(open(report))
for row in dictionary:
    print(row)
# Out:
# {'Group': '', 'Activity type': 'Computer', 'Duration': '11:14:54', 'From': '2020-01-01 20:38:54', 'To': '2020-01-02 7:07:04', 'Comment': '', '%': '45.85'}
# {'Group': 'Computer', 'Activity type': 'Internet', 'Duration': '10:25:28', 'From': '2020-01-01 20:36:33', 'To': '2020-01-01 20:38:24', 'Comment': '', '%': '42.5'}
# {'Group': 'Computer', 'Activity type': 'Movies/TV', 'Duration': '0:28:40', 'From': '2020-01-01 18:17:20', 'To': '2020-01-01 20:36:29', 'Comment': '', '%': '1.95'}
# {'Group': 'Computer', 'Activity type': 'Games', 'Duration': '0:20:46', 'From': '2020-01-01 17:48:38', 'To': '2020-01-01 18:17:18', 'Comment': '', '%': '1.41'}
# {'Group': '', 'Activity type': 'Sleeping', 'Duration': '7:17:42', 'From': '2020-01-01 17:05:58', 'To': '2020-01-01 17:37:48', 'Comment': '', '%': '29.74'}
# {'Group': '', 'Activity type': 'Hobby', 'Duration': '2:57:21', 'From': '2020-01-01 16:44:55', 'To': '2020-01-01 17:48:35', 'Comment': '', '%': '12.05'}
# {'Group': 'Hobby', 'Activity type': 'Writing', 'Duration': '2:57:21', 'From': '2020-01-01 16:29:44', 'To': '2020-01-01 16:40:53', 'Comment': '', '%': '12.05'}
# {'Group': '', 'Activity type': 'Housework', 'Duration': '1:32:29', 'From': '2020-01-01 16:27:30', 'To': '2020-01-01 16:29:41', 'Comment': '', '%': '6.28'}
# {'Group': 'Housework', 'Activity type': 'Cleaning', 'Duration': '1:21:20', 'From': '2020-01-01 14:54:56', 'To': '2020-01-01 16:27:28', 'Comment': '', '%': '5.53'}
# {'Group': 'Housework', 'Activity type': 'Cooking', 'Duration': '0:11:09', 'From': '2020-01-01 13:15:47', 'To': '2020-01-01 14:54:52', 'Comment': '', '%': '0.76'}
# {'Group': '', 'Activity type': 'Eating', 'Duration': '0:31:50', 'From': '2020-01-01 13:02:37', 'To': '2020-01-01 13:15:44', 'Comment': '', '%': '2.16'}
# {'Group': '', 'Activity type': 'Grooming', 'Duration': '0:24:27', 'From': '2020-01-01 12:04:18', 'To': '2020-01-01 13:02:36', 'Comment': '', '%': '1.66'}
# {'Group': '', 'Activity type': 'Toilet', 'Duration': '0:14:38', 'From': '2020-01-01 10:45:36', 'To': '2020-01-01 12:03:52', 'Comment': '', '%': '0.99'}
# {'Group': '', 'Activity type': '', 'Duration': '', 'From': '2020-01-01 10:05:50', 'To': '2020-01-01 10:43:15', 'Comment': '', '%': ''}
# {'Group': '', 'Activity type': '', 'Duration': '', 'From': '2020-01-01 10:04:14', 'To': '2020-01-01 10:05:24', 'Comment': '', '%': ''}
# {'Group': '', 'Activity type': '', 'Duration': '', 'From': '2020-01-01 8:52:21', 'To': '2020-01-01 10:04:12', 'Comment': '', '%': ''}
# {'Group': '', 'Activity type': '', 'Duration': '', 'From': '2020-01-01 8:48:34', 'To': '2020-01-01 8:50:50', 'Comment': '', '%': ''}
# {'Group': '', 'Activity type': '', 'Duration': '', 'From': '2020-01-01 7:27:13', 'To': '2020-01-01 8:48:33', 'Comment': '', '%': ''}
# {'Group': '', 'Activity type': '', 'Duration': '', 'From': '2020-01-01 6:56:53', 'To': '2020-01-01 7:21:20', 'Comment': '', '%': ''}
# {'Group': '', 'Activity type': '', 'Duration': '', 'From': '2020-01-01 6:55:14', 'To': '2020-01-01 6:56:52', 'Comment': '', '%': ''}
# {'Group': '', 'Activity type': '', 'Duration': '', 'From': '2020-01-01 6:45:42', 'To': '2020-01-01 6:53:21', 'Comment': '', '%': ''}
# {'Group': '', 'Activity type': '', 'Duration': '', 'From': '2020-01-01 4:03:06', 'To': '2020-01-01 6:45:39', 'Comment': '', '%': ''}
# {'Group': '', 'Activity type': '', 'Duration': '', 'From': '2020-01-01 3:56:43', 'To': '2020-01-01 4:02:15', 'Comment': '', '%': ''}
# {'Group': '', 'Activity type': '', 'Duration': '', 'From': '2019-12-31 23:07:13', 'To': '2020-01-01 3:56:37', 'Comment': '', '%': ''}

# %%
start = df['From']
end = df['To']
activity = df['Activity type']
df['Day'] = start.str[0:10]
day = df['Day']
#day = pd.to_datetime(df.From)

# %%
day
# Out:
# 0     2020-01-01
# 1     2020-01-01
# 2     2020-01-01
# 3     2020-01-01
# 4     2020-01-01
# 5     2020-01-01
# 6     2020-01-01
# 7     2020-01-01
# 8     2020-01-01
# 9     2020-01-01
# 10    2020-01-01
# 11    2020-01-01
# 12    2020-01-01
# 13    2020-01-01
# 14    2020-01-01
# 15    2020-01-01
# 16    2020-01-01
# 17    2020-01-01
# 18    2020-01-01
# 19    2020-01-01
# 20    2020-01-01
# 21    2020-01-01
# 22    2020-01-01
# 23    2019-12-31
# Name: Day, dtype: object

# %%
df['From'] = pd.to_datetime(df.From)
start = df['From']
start
# Out:
# 0    2020-01-01 20:38:54
# 1    2020-01-01 20:36:33
# 2    2020-01-01 18:17:20
# 3    2020-01-01 17:48:38
# 4    2020-01-01 17:05:58
# 5    2020-01-01 16:44:55
# 6    2020-01-01 16:29:44
# 7    2020-01-01 16:27:30
# 8    2020-01-01 14:54:56
# 9    2020-01-01 13:15:47
# 10   2020-01-01 13:02:37
# 11   2020-01-01 12:04:18
# 12   2020-01-01 10:45:36
# 13   2020-01-01 10:05:50
# 14   2020-01-01 10:04:14
# 15   2020-01-01 08:52:21
# 16   2020-01-01 08:48:34
# 17   2020-01-01 07:27:13
# 18   2020-01-01 06:56:53
# 19   2020-01-01 06:55:14
# 20   2020-01-01 06:45:42
# 21   2020-01-01 04:03:06
# 22   2020-01-01 03:56:43
# 23   2019-12-31 23:07:13
# Name: From, dtype: datetime64[ns]

# %%
df['To'] = pd.to_datetime(df.To)
end = df['To']
end
# Out:
# 0    2020-01-02 07:07:04
# 1    2020-01-01 20:38:24
# 2    2020-01-01 20:36:29
# 3    2020-01-01 18:17:18
# 4    2020-01-01 17:37:48
# 5    2020-01-01 17:48:35
# 6    2020-01-01 16:40:53
# 7    2020-01-01 16:29:41
# 8    2020-01-01 16:27:28
# 9    2020-01-01 14:54:52
# 10   2020-01-01 13:15:44
# 11   2020-01-01 13:02:36
# 12   2020-01-01 12:03:52
# 13   2020-01-01 10:43:15
# 14   2020-01-01 10:05:24
# 15   2020-01-01 10:04:12
# 16   2020-01-01 08:50:50
# 17   2020-01-01 08:48:33
# 18   2020-01-01 07:21:20
# 19   2020-01-01 06:56:52
# 20   2020-01-01 06:53:21
# 21   2020-01-01 06:45:39
# 22   2020-01-01 04:02:15
# 23   2020-01-01 03:56:37
# Name: To, dtype: datetime64[ns]

# %%
new_df = pd.DataFrame([
    dict(Start='2019-12-31 23:07:13', End='2020-01-01 3:56:37', Day="1/1/2020", Activity="Sleeping"),
    dict(Start='2020-01-01 3:56:43', End='2020-01-01 4:02:15', Day="1/1/2020", Activity="Toilet"),
    dict(Start='2020-01-01 4:03:06', End='2020-01-01 6:45:39', Day="1/1/2020", Activity="Internet"),
    dict(Start='2020-01-01 6:56:53', End='2020-01-01 7:21:20', Day="1/1/2020", Activity="Grooming"),
    dict(Start='2020-01-01 7:27:13	', End='2020-01-01 8:48:33	', Day="1/1/2020", Activity="Cleaning"),
    dict(Start='2020-01-01 8:52:21	', End='2020-01-01 10:04:12	', Day="1/1/2020", Activity="Internet"),
    dict(Start='2020-01-01 10:45:36	', End='2020-01-01 12:03:52	', Day="1/1/2020", Activity="Writing"),
    dict(Start='2020-01-01 20:38:54	', End='2020-01-02 7:07:04	', Day="1/1/2020", Activity="Sleeping"),

    #dict(Start=start, End=end, Day=day, Activity=activity),
])

fig = px.timeline(new_df, x_start="Start", x_end="End", y='Day', color="Activity"
                 )

# you can manually set the range as well
fig.update_layout(xaxis=dict(
                      title='Timestamp', 
                      tickformat = '%H:%M:%S',
                      range = ['2020-01-01 00:00:00','2020-01-01 24:00:00']
                  ))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-270-6045f474025b> in <module>
#      16
#      17 # you can manually set the range as well
# ---> 18 fig.update_layout(xaxis=dict(
#      19                       title='Timestamp',
#      20                       tickformat = '%H:%M:%S',
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/basedatatypes.py in update_layout(self, dict1, overwrite, **kwargs)
#    1401             The Figure object that the update_layout method was called on
#    1402         """
# -> 1403         self.layout.update(dict1, overwrite=overwrite, **kwargs)
#    1404         return self
#    1405
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/basedatatypes.py in update(self, dict1, overwrite, **kwargs)
#    5065             with self.figure.batch_update():
#    5066                 BaseFigure._perform_update(self, dict1, overwrite=overwrite)
# -> 5067                 BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5068         else:
#    5069             BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/basedatatypes.py in _perform_update(plotly_obj, update_obj, overwrite)
#    3883                     # Update compound objects recursively
#    3884                     # plotly_obj[key].update(val)
# -> 3885                     BaseFigure._perform_update(plotly_obj[key], val)
#    3886                 elif isinstance(validator, CompoundArrayValidator):
#    3887                     if plotly_obj[key]:
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/basedatatypes.py in _perform_update(plotly_obj, update_obj, overwrite)
#    3860                     # contain the _raise_on_invalid_property_error
#    3861                     # generated message
# -> 3862                     raise err
#    3863
#    3864             # Convert update_obj to dict
#
# ValueError: 'NoneType' object is not subscriptable
#
# Invalid value received for the 'range' property of layout.xaxis
#
#     The 'range' property is an info array that may be specified as:
#
#     * a list or tuple of 2 elements where:
# (0) The 'range[0]' property accepts values of any type
# (1) The 'range[1]' property accepts values of any type
#
# Property does not support subscripting:
# range_x
# ^^^^^
