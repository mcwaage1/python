# %%
# coin class and OOP

import random

class Coin:

    def __init__(self):
        
        self.__sideup = "Heads"
        
    def toss(self):
        
        if random.randint(0, 1) == 0:
            
            self.__sideup = "Heads"
            
        else:
            
            self.__sideup = "Tails"
            
    def get_sideup(self):
    
        return self.__sideup
            
def main():
    
    my_coin = Coin()
    
    print("This side is up:", my_coin.get_sideup())
    
    print("I am tossing the coin...")
    
    my_coin.toss()
    
    print("This side is up:", my_coin.get_sideup())

    again = input("Do you want to play again? (Yes or no.)")
    
    if again == "Y" or again == "y" or again == "Yes" or again == "yes":
                        
        how_many = int(input("How many times?"))
        
        heads = 0
            
        tails = 0
        
        for toss in range(1, how_many + 1):
            
            my_coin.toss()
            
            print("This side is up:", my_coin.get_sideup())
                        
            if my_coin.get_sideup() == "Heads":

                heads += 1

            if my_coin.get_sideup() == "Tails":

                tails += 1
            
        print("Heads was tossed", heads, "times.")
        print("Tails was tossed", tails, "times.")

main()
# Out:
# This side is up: Heads
# I am tossing the coin...
# This side is up: Tails
# Do you want to play again? (Yes or no.) yes
# How many times? 1000
# This side is up: Tails
# This side is up: Tails
# This side is up: Heads
# This side is up: Tails
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Tails
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Tails
# This side is up: Heads
# This side is up: Tails
# This side is up: Heads
# This side is up: Tails
# This side is up: Tails
# This side is up: Heads
# This side is up: Tails
# This side is up: Heads
# This side is up: Heads
# This side is up: Heads
# This side is up: Tails
# This side is up: Tails
# This side is up: Heads
# ...
