# %%
# NATO converter

def main():
    
    string = str(input("What do you want to convert to the NATO alphabet?"))

    NATO(string)
  
def NATO(string):
    
    for letter in string:
        
        if letter == 'a' or letter == "A":
            
            print("Alpha")
        
        elif letter == 'b' or letter == "B":
        
            print("Bravo")
            
        elif letter == 'c' or letter == "C":
        
            print("Charlie")
        
        elif letter == 'd' or letter == "D":
        
            print("Delta")
            
        elif letter == 'e' or letter == "E":
        
            print("Echo")
            
        elif letter == 'f' or letter == "F":
        
            print("Foxtrot")
            
        elif letter == 'g' or letter == "G":
        
            print("Golf")
            
        elif letter == 'h' or letter == "H":
        
            print("Hotel")
            
        elif letter == 'i' or letter == "I":
        
            print("India")
            
        elif letter == 'j' or letter == "J":
        
            print("Juliett")
            
        elif letter == 'k' or letter == "K":
        
            print("Kilo")
            
        elif letter == 'l' or letter == "L":
        
            print("Lima")
            
        elif letter == 'm' or letter == "M":
        
            print("Mike")
            
        elif letter == 'n' or letter == "N":
        
            print("November")
            
        elif letter == 'o' or letter == "O":
        
            print("Oscar")
        
        elif letter == 'p' or letter == "P":
        
            print("Papa")
            
        elif letter == 'q' or letter == "Q":
        
            print("Quebec")
            
        elif letter == 'r' or letter == "R":
        
            print("Romeo")
            
        elif letter == 's' or letter == "S":
        
            print("Sierra")
            
        elif letter == 't' or letter == "T":
        
            print("Tango")
            
        elif letter == 'u' or letter == "U":
        
            print("Uniform")
            
        elif letter == 'v' or letter == "V":
        
            print("Victor")
            
        elif letter == 'w' or letter == "W":
        
            print("Whiskey")
            
        elif letter == 'x' or letter == "X":
        
            print("X-ray")
            
        elif letter == 'y' or letter == "Y":
        
            print("Yankee")
            
        elif letter == 'z' or letter == "Z":
        
            print("Zulu")
            
        elif letter == '0':
            
            print("Zero")
            
        elif letter == '1':
        
            print("One")
            
        elif letter == '2':
            
            print("Two")
            
        elif letter == '3':
            
            print("Three")
            
        elif letter == '4':
            
            print("Four")
            
        elif letter == '5':
            
            print("Five")
        
        elif letter == '6':
        
            print("Six")
            
        elif letter == '7':
            
            print("Seven")
            
        elif letter == '8':
            
            print("Eight")
            
        elif letter == '9':
            
            print("Nine")
            
        elif letter == '10':
            
            print("Ten")
            
        else:
            
            print("")
        
main()
# Out:
# What do you want to convert to the NATO alphabet? Your mom gay
# Yankee
# Oscar
# Uniform
# Romeo
#
# Mike
# Oscar
# Mike
#
# Golf
# Alpha
# Yankee
